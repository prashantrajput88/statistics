# %%
 import  pandas as pd

# %%
df=pd.read_csv("e:/scientist/dataset/analysis/IPL Matches 2008-2020.csv")
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore   4/18/2008     BB McCullum
# 1     335983  Chandigarh   4/19/2008      MEK Hussey
# 2     335984       Delhi   4/19/2008     MF Maharoof
# 3     335985      Mumbai   4/20/2008      MV Boucher
# 4     335986     Kolkata   4/20/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai   9/28/2020  AB de Villiers
# 812  1237177       Dubai   11/5/2020       JJ Bumrah
# 813  1237178   Abu Dhabi   11/6/2020   KS Williamson
# 814  1237180   Abu Dhabi   11/8/2020      MP Stoinis
# 815  1237181       Dubai  11/10/2020        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # Clean up the data

# %%
df.drop("method",axis=1,inplace=True)

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore   4/18/2008     BB McCullum
# 1     335983  Chandigarh   4/19/2008      MEK Hussey
# 2     335984       Delhi   4/19/2008     MF Maharoof
# 3     335985      Mumbai   4/20/2008      MV Boucher
# 4     335986     Kolkata   4/20/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai   9/28/2020  AB de Villiers
# 812  1237177       Dubai   11/5/2020       JJ Bumrah
# 813  1237178   Abu Dhabi   11/6/2020   KS Williamson
# 814  1237180   Abu Dhabi   11/8/2020      MP Stoinis
# 815  1237181       Dubai  11/10/2020        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.dropna(axis=0,subset=["city","result_margin","player_of_match"],inplace=True)

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore   4/18/2008     BB McCullum
# 1     335983  Chandigarh   4/19/2008      MEK Hussey
# 2     335984       Delhi   4/19/2008     MF Maharoof
# 3     335985      Mumbai   4/20/2008      MV Boucher
# 4     335986     Kolkata   4/20/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 810  1216546       Dubai  10/20/2020        S Dhawan
# 812  1237177       Dubai   11/5/2020       JJ Bumrah
# 813  1237178   Abu Dhabi   11/6/2020   KS Williamson
# 814  1237180   Abu Dhabi   11/8/2020      MP Stoinis
# 815  1237181       Dubai  11/10/2020        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # Check Null Values in the dataset

# %%
df.isnull().sum()
# Out:
# id                 0
# city               0
# date               0
# player_of_match    0
# venue              0
# neutral_venue      0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# eliminator         0
# umpire1            0
# umpire2            0
# dtype: int64

# %% [markdown]
#   # Duplicates values in the data

# %%
df.drop_duplicates(subset=["date"])
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore   4/18/2008     BB McCullum
# 1     335983  Chandigarh   4/19/2008      MEK Hussey
# 3     335985      Mumbai   4/20/2008      MV Boucher
# 5     335987      Jaipur   4/21/2008       SR Watson
# 6     335988   Hyderabad   4/22/2008        V Sehwag
# ..       ...         ...         ...             ...
# 810  1216546       Dubai  10/20/2020        S Dhawan
# 812  1237177       Dubai   11/5/2020       JJ Bumrah
# 813  1237178   Abu Dhabi   11/6/2020   KS Williamson
# 814  1237180   Abu Dhabi   11/8/2020      MP Stoinis
# 815  1237181       Dubai  11/10/2020        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 3                              Wankhede Stadium              0
# 5                        Sawai Mansingh Stadium              0
# ...

# %% [markdown]
# # Name rename label of the data

# %%
df.rename({"player_of_match":"player   of the match"},axis=1,inplace=False)
# Out:
#           id        city        date player   of the match  \
# 0     335982   Bangalore   4/18/2008           BB McCullum
# 1     335983  Chandigarh   4/19/2008            MEK Hussey
# 2     335984       Delhi   4/19/2008           MF Maharoof
# 3     335985      Mumbai   4/20/2008            MV Boucher
# 4     335986     Kolkata   4/20/2008             DJ Hussey
# ..       ...         ...         ...                   ...
# 810  1216546       Dubai  10/20/2020              S Dhawan
# 812  1237177       Dubai   11/5/2020             JJ Bumrah
# 813  1237178   Abu Dhabi   11/6/2020         KS Williamson
# 814  1237180   Abu Dhabi   11/8/2020            MP Stoinis
# 815  1237181       Dubai  11/10/2020              TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# ...

# %% [markdown]
# # Index rename of the data

# %%
df.rename({2:"INDIA"},axis=0)
# Out:
#             id        city        date player_of_match  \
# 0       335982   Bangalore   4/18/2008     BB McCullum
# 1       335983  Chandigarh   4/19/2008      MEK Hussey
# INDIA   335984       Delhi   4/19/2008     MF Maharoof
# 3       335985      Mumbai   4/20/2008      MV Boucher
# 4       335986     Kolkata   4/20/2008       DJ Hussey
# ...        ...         ...         ...             ...
# 810    1216546       Dubai  10/20/2020        S Dhawan
# 812    1237177       Dubai   11/5/2020       JJ Bumrah
# 813    1237178   Abu Dhabi   11/6/2020   KS Williamson
# 814    1237180   Abu Dhabi   11/8/2020      MP Stoinis
# 815    1237181       Dubai  11/10/2020        TA Boult
#
#                                             venue  neutral_venue  \
# 0                           M Chinnaswamy Stadium              0
# 1      Punjab Cricket Association Stadium, Mohali              0
# INDIA                            Feroz Shah Kotla              0
# ...

# %% [markdown]
# #  Display top 5 Rows of the data

# %%
df.head()
# Out:
#        id        city       date player_of_match  \
# 0  335982   Bangalore  4/18/2008     BB McCullum
# 1  335983  Chandigarh  4/19/2008      MEK Hussey
# 2  335984       Delhi  4/19/2008     MF Maharoof
# 3  335985      Mumbai  4/20/2008      MV Boucher
# 4  335986     Kolkata  4/20/2008       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %% [markdown]
# # Display last 5 Rows of the data

# %%
df.tail()
# Out:
#           id       city        date player_of_match  \
# 810  1216546      Dubai  10/20/2020        S Dhawan
# 812  1237177      Dubai   11/5/2020       JJ Bumrah
# 813  1237178  Abu Dhabi   11/6/2020   KS Williamson
# 814  1237180  Abu Dhabi   11/8/2020      MP Stoinis
# 815  1237181      Dubai  11/10/2020        TA Boult
#
#                                    venue  neutral_venue  \
# 810  Dubai International Cricket Stadium              0
# 812  Dubai International Cricket Stadium              0
# 813                 Sheikh Zayed Stadium              0
# 814                 Sheikh Zayed Stadium              0
# 815  Dubai International Cricket Stadium              0
#
#                            team1                team2          toss_winner  \
# 810               Delhi Capitals      Kings XI Punjab       Delhi Capitals
# 812               Mumbai Indians       Delhi Capitals       Delhi Capitals
# 813  Royal Challengers Bangalore  Sunrisers Hyderabad  Sunrisers Hyderabad
# ...

# %% [markdown]
# # Find shape of the data ( Number of Rows & Number of Columns)

# %%
df.shape
# Out:
# (786, 16)

# %% [markdown]
# #  Get Information about our dataset like total number rows .Total number of cloumns., datatypes of each column and memory requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 786 entries, 0 to 815
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               786 non-null    int64
#  1   city             786 non-null    object
#  2   date             786 non-null    object
#  3   player_of_match  786 non-null    object
#  4   venue            786 non-null    object
#  5   neutral_venue    786 non-null    int64
#  6   team1            786 non-null    object
#  7   team2            786 non-null    object
#  8   toss_winner      786 non-null    object
#  9   toss_decision    786 non-null    object
#  10  winner           786 non-null    object
#  11  result           786 non-null    object
#  12  result_margin    786 non-null    float64
#  13  eliminator       786 non-null    object
#  14  umpire1          786 non-null    object
#  15  umpire2          786 non-null    object
# dtypes: float64(1), int64(2), object(13)
# ...

# %% [markdown]
#  # Check  Null values in the Dataset

# %%
df.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 810    0
# 812    0
# 813    0
# 814    0
# 815    0
# Length: 786, dtype: int64

# %%
df.isnull().sum(axis=0)
# Out:
# id                 0
# city               0
# date               0
# player_of_match    0
# venue              0
# neutral_venue      0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# eliminator         0
# umpire1            0
# umpire2            0
# dtype: int64

# %% [markdown]
# # That  are unique  city in the ipl data

# %%
df["city"].nunique()
# Out:
# 32

# %%
df["city"].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', 'Rajkot', 'Kanpur', 'Bengaluru', 'Sharjah', 'Dubai'],
#       dtype=object)

# %% [markdown]
# # All ipl team and  count all match

# %%
df["city"].value_counts()
# Out:
# city
# Mumbai            100
# Kolkata            77
# Delhi              72
# Hyderabad          63
# Bangalore          62
# Chandigarh         56
# Chennai            56
# Jaipur             47
# Pune               38
# Abu Dhabi          27
# Dubai              23
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Sharjah            12
# Ahmedabad          11
# Dharamsala          9
# Rajkot              9
# Indore              9
# Johannesburg        8
# Cuttack             7
# Port Elizabeth      7
# Ranchi              7
# Raipur              6
# Cape Town           6
# Kochi               5
# Kanpur              4
# Nagpur              3
# East London         3
# Kimberley           3
# Bloemfontein        2
# Name: count, dtype: int64

# %% [markdown]
# #  All  team playing in the ipl

# %%
df["team2"].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Deccan Chargers',
#        'Kings XI Punjab', 'Delhi Daredevils', 'Mumbai Indians',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %% [markdown]
#  # Analyics data team [Mumbai  Indians  and   Royal Challengers Bangalore]

# %%
# ONLY 10 MATCH
df[(df["city"]=="Mumbai") & (df["team2"]=="Royal Challengers Bangalore")].shape
# Out:
# (10, 16)

# %%
#df[df["player_of_match"]=="MV Boucher"]

# %%
df[(df["team1"]=="Mumbai Indians") &(df["team2"]=="Royal Challengers Bangalore") & (df["toss_winner"]=="Mumbai Indians")]
# Out:
#           id    city       date player_of_match              venue  \
# 3     335985  Mumbai  4/20/2008      MV Boucher   Wankhede Stadium
# 128   419119  Mumbai  3/20/2010       JH Kallis  Brabourne Stadium
# 357   598033  Mumbai  4/27/2013        DR Smith   Wankhede Stadium
# 530   980927  Mumbai  4/20/2016       RG Sharma   Wankhede Stadium
# 726  1178406  Mumbai  4/15/2019      SL Malinga   Wankhede Stadium
#
#      neutral_venue           team1                        team2  \
# 3                0  Mumbai Indians  Royal Challengers Bangalore
# 128              0  Mumbai Indians  Royal Challengers Bangalore
# 357              0  Mumbai Indians  Royal Challengers Bangalore
# 530              0  Mumbai Indians  Royal Challengers Bangalore
# 726              0  Mumbai Indians  Royal Challengers Bangalore
#
#         toss_winner toss_decision                       winner   result  \
# 3    Mumbai Indians           bat  Royal Challengers Bangalore  wickets
# ...

# %%
df[(df["team1"]=="Mumbai Indians") &(df["team2"]=="Royal Challengers Bangalore")& (df["toss_winner"]=="Royal Challengers Bangalore")]
# Out:
#           id    city       date player_of_match             venue  \
# 300   548360  Mumbai   5/9/2012        CH Gayle  Wankhede Stadium
# 424   733983  Mumbai   5/6/2014       RG Sharma  Wankhede Stadium
# 502   829795  Mumbai  5/10/2015  AB de Villiers  Wankhede Stadium
# 613  1082628  Mumbai   5/1/2017       RG Sharma  Wankhede Stadium
# 649  1136574  Mumbai  4/17/2018       RG Sharma  Wankhede Stadium
#
#      neutral_venue           team1                        team2  \
# 300              0  Mumbai Indians  Royal Challengers Bangalore
# 424              0  Mumbai Indians  Royal Challengers Bangalore
# 502              0  Mumbai Indians  Royal Challengers Bangalore
# 613              0  Mumbai Indians  Royal Challengers Bangalore
# 649              0  Mumbai Indians  Royal Challengers Bangalore
#
#                      toss_winner toss_decision                       winner  \
# 300  Royal Challengers Bangalore         field  Royal Challengers Bangalore
# ...

# %%
df[(df["team1"]=="Mumbai Indians") &(df["team2"]=='Kolkata Knight Riders')].shape
# Out:
# (13, 16)

# %%
df[(df["team1"]=="Mumbai Indians") & (df["team2"]=="Kolkata Knight Riders")]
# Out:
#           id       city       date player_of_match                  venue  \
# 39    336021     Mumbai  5/16/2008      SM Pollock       Wankhede Stadium
# 131   419122     Mumbai  3/22/2010    SR Tendulkar      Brabourne Stadium
# 245   501269     Mumbai  5/25/2011        MM Patel       Wankhede Stadium
# 310   548370     Mumbai  5/16/2012       SP Narine       Wankhede Stadium
# 374   598050     Mumbai   5/7/2013    SR Tendulkar       Wankhede Stadium
# 398   729279  Abu Dhabi  4/16/2014       JH Kallis   Sheikh Zayed Stadium
# 507   829805     Mumbai  5/14/2015       HH Pandya       Wankhede Stadium
# 540   980947     Mumbai  4/28/2016       RG Sharma       Wankhede Stadium
# 583  1082597     Mumbai   4/9/2017          N Rana       Wankhede Stadium
# 634  1082649  Bangalore  5/19/2017       KV Sharma  M Chinnaswamy Stadium
# 672  1136597     Mumbai   5/6/2018       HH Pandya       Wankhede Stadium
# 751  1178431     Mumbai   5/5/2019       HH Pandya       Wankhede Stadium
# ...

# %%
df.value_counts("player_of_match")
# Out:
# player_of_match
# CH Gayle          22
# AB de Villiers    22
# RG Sharma         18
# MS Dhoni          17
# DA Warner         17
#                   ..
# KMA Paul           1
# KK Cooper          1
# KK Ahmed           1
# K Rabada           1
# Z Khan             1
# Name: count, Length: 232, dtype: int64

# %%
df.value_counts("venue")
# Out:
# venue
# Eden Gardens                                            77
# Wankhede Stadium                                        72
# Feroz Shah Kotla                                        72
# Rajiv Gandhi International Stadium, Uppal               63
# M Chinnaswamy Stadium                                   62
# MA Chidambaram Stadium, Chepauk                         56
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Sheikh Zayed Stadium                                    27
# Dubai International Cricket Stadium                     23
# Punjab Cricket Association IS Bindra Stadium, Mohali    21
# Maharashtra Cricket Association Stadium                 21
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# Kingsmead                                               15
# M.Chinnaswamy Stadium                                   14
# ...

# %%
df[df["mumbai"]==
# Out:
#   Cell In[28], line 1
#     df[df["mumbai"]==
#                      ^
# SyntaxError: incomplete input

# %% [markdown]
# # The all match in the city

# %%
df.city.value_counts()
